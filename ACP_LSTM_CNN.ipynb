# %%
# !pip install -q -U keras-tuner # install keras-tuner for hyper-parameters optimization
# Out:
#      |████████████████████████████████| 135 kB 2.1 MB/s
#      |████████████████████████████████| 1.6 MB 16.3 MB/s

# %%
import numpy as np 
import pandas as pd 

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential, Model
from keras.layers import Dense, Embedding, LSTM, Dropout, Conv1D, BatchNormalization, MaxPooling1D, Flatten
from keras.callbacks import EarlyStopping, ModelCheckpoint
from google.colab import drive
from sklearn.model_selection import RepeatedStratifiedKFold, StratifiedKFold
import keras_tuner
from kerastuner.tuners import RandomSearch
from matplotlib import pyplot as plt

# Global variables
checkpoint_filepath = '/tmp/checkpoint'
BATCH_SIZE = 64
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   if sys.path[0] == '':

# %% [markdown]
# # Data Loading and Pre-processing

# %%
#drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#domain = "Social_Networking"
#domain = "Games"
domain = "Productivity"

dataset_url = ""

if domain == "Social_Networking":
  dataset_url = "https://drive.google.com/uc?id=1eH5TJgRhfYQZzhRnmQ-oUAtLGw4PjHVb&export=download"
elif domain == "Games":
  dataset_url = "https://drive.google.com/uc?id=1pHfUvHZP5iJeVU1_PUGm9RWim4xd34F5&export=download"
elif domain == "Social_Networking":
  dataset_url = "https://drive.google.com/uc?id=1Qy_zC7L-EGTXAa4Tzqw5-8cKxHyaDeep&export=download"

# %%
df = pd.read_csv(dataset_url)
df.head()
# Out:
#          domain                       app  \
# 0  productivity                notability
# 1  productivity     gmail-email-by-google
# 2  productivity     gmail-email-by-google
# 3  productivity  evernote-notes-organizer
# 4  productivity                  things-3
#
#                               review_id                           sentence_id  \
# 0  3dd4f1ab-9433-49b1-91c9-5391373063f8  c6c55c2d-2257-4da4-a959-6622d8619a54
# 1  43e1aef5-d46a-48bf-a672-cc8bf8410178  6dead894-5be5-4131-8c52-0a0bcc2cfd2a
# 2  9aac0ac9-bdd8-42a2-88c0-648d6f6b2cfd  984fe632-4815-46af-8552-6cca28bb995a
# 3  0877dc72-b915-49ae-af9b-fd49de658f51  fce9100d-528b-4d3b-b338-a8187340a5a3
# 4  8400a21d-e0b9-44c9-a242-8ab68efd7e86  a81e8c27-a6a6-4c25-8bb4-75da38314822
#
#                                                title  \
# 0  *updated* Fixed some glitches, bad changes, ne...
# 1                   Works for email, no split screen
# 2                                         Attachment
# 3                        Latest upgrade a total FAIL
# 4                                    Dream come True
#
#                                               review  \
# 0  *new update* they fixed some import issues and...
# 1  This app works well for email, particularly my...
# 2  I acknowledge that one star is a severe respon...
# 3  I want to change my rating from one star to Ze...
# 4  I am one of those who seldom spare time to wri...
#
#                                             sentence  rating  is_opinion  \
# 0  For example, main divider --> dividers A, B, &...       5        True
# 1  Even calendar allows a slide over... please ad...       4        True
# 2  I was attempting to attach an important, time ...       1        True
# 3  However, the new version just updated to my iP...       1        True
# 4  You don’t want to worry about figuring out the...       5        True
#
#         category      term  from    to sentiment  category_id  sentiment_id  \
# 0        general   divider  19.0  26.0  positive            6             1
# 1  effectiveness  calendar   6.0  14.0  positive            3             1
# 2    reliability  document  57.0  65.0  positive            8             1
# 3  compatibility    update  31.0  37.0  negative            2             0
# 4        general  reminder  59.0  67.0  positive            6             1
#
#   category_id_sentiment_id
# 0                      6_1
# 1                      3_1
# 2                      8_1
# 3                      2_0
# 4                      6_1

# %%
# Split data into X and label
X = df["sentence"]
Y = df["sentiment_id"]

# %%
# Display vocabulary size 
num_words = len(set([word.lower() for word in X]))
print("Vocabulary size: {}".format(num_words))

# Display dataset size
print("Dataset size: {}".format(len(X)))
# Out:
# Vocabulary size: 3354
# Dataset size: 3774

# %%
# Pre-process text
max_len = len(max(X, key=len))
tok = Tokenizer()
tok.fit_on_texts(X)
X = tok.texts_to_sequences(X)
X = pad_sequences(X, maxlen=max_len)

# %% [markdown]
# # DL Models Utils

# %% [markdown]
# ## Construct models with different hyperparameters

# %%
# Construct LSTM

def build_LSTM_model(hp):

    model = Sequential()
    model.add(Embedding(len(tok.word_index), 128))

    model.add(LSTM(
        hp.Int('lstm_first_units', min_value=32, max_value=128, step=32),
        return_sequences=True)
    )
    
    for i in range(hp.Int('n_layers', 1, 4)):

        model.add(LSTM(
            hp.Int(f'lstm_{i+2}_units', min_value=32, max_value=128, step=32),
            return_sequences=True)
        )
        
    model.add(LSTM(hp.Int('lstm_last_units', min_value=32, max_value=128, step=32)))
        
    model.add(Dropout(hp.Float('Dropout_rate', min_value=0, max_value=0.5, step=0.1)))

    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])

    return model

# %%
# CNN
def build_CNN_model(hp):

    # define filters hyper-parameters space [32, 64]
    hp_filters = hp.Int('filters', min_value = 32, max_value = 128, step = 32)


    # create model object
    model = Sequential()

    model.add(Embedding(len(tok.word_index) + 1, 128))

    # ---- Tune the number of CNN blocks: 1-3 ----
    # (1 CNN block = convolution, batch normalization, convolution, batch normalization, max pooling, dropout)
    for i in range(1, hp.Int("num_conv_blocks", 2, 4)):

      model.add(Conv1D(filters = hp_filters * i, kernel_size = (3), activation = 'relu'))
      model.add(BatchNormalization())
      model.add(Conv1D(filters = hp_filters * i, kernel_size = (3), activation = 'relu'))
      model.add(BatchNormalization())
      model.add(MaxPooling1D((2)))
      model.add(Dropout(0.2 + (i/10)))

    # ---- Fully-connected layer ----
    #model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    # ---- Output layer ----
    model.add(Dense(1, activation='sigmoid'))
  
    # ---- Compile model ----
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])

    return model

# %% [markdown]
# ## Define Callbacks

# %%
# Early stopping callback
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 5)

# Checkpoint callback
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only = True,
    monitor='val_loss',
    save_best_only=True)

# %% [markdown]
# ## Cross Validation

# %%
def cross_validation(best_hps):

  # define 10-fold cross validation test harness
  kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=10, random_state=11)
  cvscores = []
  fold_id = 1

  for train, test in kfold.split(X, Y):

    # Get the best model
    model = tuner.hypermodel.build(best_hps)

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Fit the model
    model.fit(
        X[train],
        Y[train],
        batch_size=BATCH_SIZE,
        epochs=100,
        validation_split=0.2,
        callbacks=[early_stopping_callback, model_checkpoint_callback],
        verbose=0)
      
    # evaluate the model
    scores = model.evaluate(X[test], Y[test], verbose=0)
    print("Accuracy of fold (%s) = %.2f%%" % (fold_id, scores[1]*100))
    fold_id = fold_id + 1
    cvscores.append(scores[1] * 100)
    
  print("Averaged accuracy = %.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))

# %% [markdown]
# # Experiments

# %% [markdown]
# ## LSTM

# %%
# Tuning LSTM
tuner= RandomSearch(
        build_LSTM_model,
        objective='val_loss',
        max_trials=10,
        overwrite=True
        )

tuner.search(X,
             Y,
             batch_size=BATCH_SIZE,
             epochs=100,
             callbacks = [early_stopping_callback],
             validation_split = 0.2)

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters()[0]

# Get the best model
hypermodel = tuner.hypermodel.build(best_hps)

# Summary of the best model
print("Best Model Summary:")
hypermodel.summary()

# Retrain the best model with cross validation
cross_validation(best_hps)
# Out:
# Trial 10 Complete [00h 00m 20s]
# val_loss: 0.5963333249092102
#
# Best val_loss So Far: 0.5747926831245422
# Total elapsed time: 00h 04m 11s
# Best Model Summary:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 128)         463360
#
#  lstm_4 (LSTM)               (None, None, 96)          86400
#
#  lstm_5 (LSTM)               (None, None, 32)          16512
#
#  lstm_6 (LSTM)               (None, None, 128)         82432
#
#  lstm_7 (LSTM)               (None, 96)                86400
#
#  dropout_1 (Dropout)         (None, 96)                0
#
#  dense_1 (Dense)             (None, 1)                 97
#
# =================================================================
# Total params: 735,201
# Trainable params: 735,201
# Non-trainable params: 0
# _________________________________________________________________
# Accuracy of fold (1) = 69.55%
# Accuracy of fold (2) = 69.87%
# Accuracy of fold (3) = 71.47%
# Accuracy of fold (4) = 67.31%
# Accuracy of fold (5) = 70.83%
# Accuracy of fold (6) = 67.63%
# Accuracy of fold (7) = 68.91%
# Accuracy of fold (8) = 70.51%
# Accuracy of fold (9) = 67.85%
# Accuracy of fold (10) = 67.85%
# Accuracy of fold (11) = 64.42%
# Accuracy of fold (12) = 69.23%
# Accuracy of fold (13) = 69.55%
# Accuracy of fold (14) = 66.99%
# Accuracy of fold (15) = 72.44%
# Accuracy of fold (16) = 74.68%
# Accuracy of fold (17) = 71.79%
# Accuracy of fold (18) = 65.38%
# Accuracy of fold (19) = 70.74%
# Accuracy of fold (20) = 67.20%
# Accuracy of fold (21) = 69.23%
# Accuracy of fold (22) = 66.67%
# Accuracy of fold (23) = 68.59%
# Accuracy of fold (24) = 67.31%
# Accuracy of fold (25) = 67.63%
# Accuracy of fold (26) = 73.72%
# Accuracy of fold (27) = 69.87%
# Accuracy of fold (28) = 70.51%
# Accuracy of fold (29) = 69.13%
# Accuracy of fold (30) = 67.20%
# Accuracy of fold (31) = 67.31%
# Accuracy of fold (32) = 69.87%
# Accuracy of fold (33) = 70.19%
# Accuracy of fold (34) = 72.12%
# Accuracy of fold (35) = 68.91%
# Accuracy of fold (36) = 68.27%
# Accuracy of fold (37) = 69.55%
# Accuracy of fold (38) = 67.31%
# Accuracy of fold (39) = 70.42%
# Accuracy of fold (40) = 66.88%
# Accuracy of fold (41) = 67.95%
# Accuracy of fold (42) = 66.35%
# Accuracy of fold (43) = 69.55%
# Accuracy of fold (44) = 63.46%
# Accuracy of fold (45) = 66.99%
# Accuracy of fold (46) = 67.95%
# Accuracy of fold (47) = 68.27%
# Accuracy of fold (48) = 73.72%
# Accuracy of fold (49) = 71.38%
# Accuracy of fold (50) = 67.85%
# Accuracy of fold (51) = 68.91%
# Accuracy of fold (52) = 70.19%
# Accuracy of fold (53) = 69.23%
# Accuracy of fold (54) = 72.76%
# Accuracy of fold (55) = 66.99%
# Accuracy of fold (56) = 72.12%
# Accuracy of fold (57) = 73.08%
# Accuracy of fold (58) = 70.51%
# Accuracy of fold (59) = 66.24%
# Accuracy of fold (60) = 68.81%
# Accuracy of fold (61) = 66.35%
# Accuracy of fold (62) = 69.55%
# Accuracy of fold (63) = 70.83%
# Accuracy of fold (64) = 71.15%
# Accuracy of fold (65) = 68.91%
# Accuracy of fold (66) = 68.91%
# Accuracy of fold (67) = 69.55%
# Accuracy of fold (68) = 70.19%
# Accuracy of fold (69) = 73.31%
# Accuracy of fold (70) = 68.17%
# Accuracy of fold (71) = 69.55%
# Accuracy of fold (72) = 74.36%
# Accuracy of fold (73) = 67.31%
# Accuracy of fold (74) = 70.83%
# Accuracy of fold (75) = 72.12%
# Accuracy of fold (76) = 66.35%
# Accuracy of fold (77) = 65.06%
# Accuracy of fold (78) = 70.51%
# Accuracy of fold (79) = 71.70%
# Accuracy of fold (80) = 69.45%
# Accuracy of fold (81) = 66.67%
# Accuracy of fold (82) = 71.15%
# Accuracy of fold (83) = 66.03%
# Accuracy of fold (84) = 67.63%
# Accuracy of fold (85) = 66.03%
# Accuracy of fold (86) = 70.51%
# Accuracy of fold (87) = 73.08%
# Accuracy of fold (88) = 70.83%
# Accuracy of fold (89) = 70.74%
# Accuracy of fold (90) = 67.20%
# Accuracy of fold (91) = 69.23%
# Accuracy of fold (92) = 66.35%
# Accuracy of fold (93) = 70.83%
# Accuracy of fold (94) = 71.47%
# Accuracy of fold (95) = 65.06%
# Accuracy of fold (96) = 71.15%
# Accuracy of fold (97) = 71.47%
# Accuracy of fold (98) = 68.59%
# Accuracy of fold (99) = 67.20%
# Accuracy of fold (100) = 72.03%
# Averaged accuracy = 69.25% (+/- 2.31%)

# %% [markdown]
# ## CNN

# %%
# Tuning CNN
tuner= RandomSearch(
        build_CNN_model,
        objective='val_loss',
        max_trials=10,
        overwrite=True
        )

tuner.search(X,
             Y,
             batch_size=BATCH_SIZE,
             epochs=100,
             callbacks = [early_stopping_callback],
             validation_split = 0.2)

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters()[0]

# Get the best model
hypermodel = tuner.hypermodel.build(best_hps)

# Summary of the best model
print("Best Model Summary:")
hypermodel.summary()

# Retrain the best model with cross validation
cross_validation(best_hps)
# Out:
# Trial 10 Complete [00h 00m 13s]
# val_loss: 0.6906360983848572
#
# Best val_loss So Far: 0.6889340281486511
# Total elapsed time: 00h 01m 51s
# Best Model Summary:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 128)         560128
#
#  conv1d_4 (Conv1D)           (None, None, 32)          12320
#
#  batch_normalization_5 (Batc  (None, None, 32)         128
#  hNormalization)
#
#  conv1d_5 (Conv1D)           (None, None, 32)          3104
#
#  batch_normalization_6 (Batc  (None, None, 32)         128
#  hNormalization)
#
#  max_pooling1d_2 (MaxPooling  (None, None, 32)         0
#  1D)
#
#  dropout_3 (Dropout)         (None, None, 32)          0
#
#  conv1d_6 (Conv1D)           (None, None, 64)          6208
#
#  batch_normalization_7 (Batc  (None, None, 64)         256
#  hNormalization)
#
#  conv1d_7 (Conv1D)           (None, None, 64)          12352
#
#  batch_normalization_8 (Batc  (None, None, 64)         256
#  hNormalization)
#
#  max_pooling1d_3 (MaxPooling  (None, None, 64)         0
#  1D)
#
#  dropout_4 (Dropout)         (None, None, 64)          0
#
#  dense_2 (Dense)             (None, None, 128)         8320
#
#  batch_normalization_9 (Batc  (None, None, 128)        512
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, None, 128)         0
#
#  dense_3 (Dense)             (None, None, 1)           129
#
# =================================================================
# Total params: 603,841
# Trainable params: 603,201
# Non-trainable params: 640
# _________________________________________________________________
# Accuracy of fold (1) = 52.84%
# Accuracy of fold (2) = 47.66%
# Accuracy of fold (3) = 53.65%
# Accuracy of fold (4) = 52.17%
# Accuracy of fold (5) = 47.83%
# Accuracy of fold (6) = 50.06%
# Accuracy of fold (7) = 52.75%
# Accuracy of fold (8) = 47.75%
# Accuracy of fold (9) = 52.69%
# Accuracy of fold (10) = 52.26%
# Accuracy of fold (11) = 53.66%
# Accuracy of fold (12) = 47.64%
# Accuracy of fold (13) = 54.14%
# Accuracy of fold (14) = 51.53%
# Accuracy of fold (15) = 47.75%
# Accuracy of fold (16) = 49.64%
# Accuracy of fold (17) = 47.91%
# Accuracy of fold (18) = 52.27%
# Accuracy of fold (19) = 52.56%
# Accuracy of fold (20) = 47.75%
# Accuracy of fold (21) = 52.38%
# Accuracy of fold (22) = 52.38%
# Accuracy of fold (23) = 52.69%
# Accuracy of fold (24) = 52.14%
# Accuracy of fold (25) = 52.60%
# Accuracy of fold (26) = 47.75%
# Accuracy of fold (27) = 49.62%
# Accuracy of fold (28) = 52.26%
# Accuracy of fold (29) = 52.07%
# Accuracy of fold (30) = 53.16%
# Accuracy of fold (31) = 52.37%
# Accuracy of fold (32) = 52.50%
# Accuracy of fold (33) = 53.44%
# Accuracy of fold (34) = 51.97%
# Accuracy of fold (35) = 48.39%
# Accuracy of fold (36) = 53.03%
# Accuracy of fold (37) = 52.27%
# Accuracy of fold (38) = 52.25%
# Accuracy of fold (39) = 51.94%
# Accuracy of fold (40) = 47.75%
# Accuracy of fold (41) = 53.79%
# Accuracy of fold (42) = 52.38%
# Accuracy of fold (43) = 52.39%
# Accuracy of fold (44) = 52.68%
# Accuracy of fold (45) = 47.75%
# Accuracy of fold (46) = 52.35%
# Accuracy of fold (47) = 52.82%
# Accuracy of fold (48) = 52.25%
# Accuracy of fold (49) = 47.94%
# Accuracy of fold (50) = 52.30%
# Accuracy of fold (51) = 52.46%
# Accuracy of fold (52) = 53.87%
# Accuracy of fold (53) = 47.62%
# Accuracy of fold (54) = 52.12%
# Accuracy of fold (55) = 52.39%
# Accuracy of fold (56) = 52.54%
# Accuracy of fold (57) = 52.27%
# Accuracy of fold (58) = 52.19%
# Accuracy of fold (59) = 52.33%
# Accuracy of fold (60) = 52.45%
# Accuracy of fold (61) = 52.38%
# Accuracy of fold (62) = 52.52%
# Accuracy of fold (63) = 52.51%
# Accuracy of fold (64) = 48.99%
# Accuracy of fold (65) = 52.37%
# Accuracy of fold (66) = 52.85%
# Accuracy of fold (67) = 52.22%
# Accuracy of fold (68) = 49.42%
# Accuracy of fold (69) = 52.25%
# Accuracy of fold (70) = 52.32%
# Accuracy of fold (71) = 47.62%
# Accuracy of fold (72) = 52.36%
# Accuracy of fold (73) = 52.38%
# Accuracy of fold (74) = 52.12%
# Accuracy of fold (75) = 52.28%
# Accuracy of fold (76) = 53.22%
# Accuracy of fold (77) = 52.25%
# Accuracy of fold (78) = 53.30%
# Accuracy of fold (79) = 49.15%
# Accuracy of fold (80) = 52.25%
# Accuracy of fold (81) = 54.01%
# Accuracy of fold (82) = 47.76%
# Accuracy of fold (83) = 53.69%
# Accuracy of fold (84) = 47.88%
# Accuracy of fold (85) = 52.23%
# Accuracy of fold (86) = 52.19%
# Accuracy of fold (87) = 52.25%
# Accuracy of fold (88) = 52.18%
# Accuracy of fold (89) = 52.25%
# Accuracy of fold (90) = 47.97%
# Accuracy of fold (91) = 48.01%
# Accuracy of fold (92) = 52.63%
# Accuracy of fold (93) = 52.99%
# Accuracy of fold (94) = 52.60%
# Accuracy of fold (95) = 47.75%
# Accuracy of fold (96) = 47.86%
# Accuracy of fold (97) = 52.60%
# Accuracy of fold (98) = 52.25%
# Accuracy of fold (99) = 52.25%
# Accuracy of fold (100) = 52.27%
# Averaged accuracy = 51.43% (+/- 2.00%)
